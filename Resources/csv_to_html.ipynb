# %%
# Import dependencies
import pandas as pd

# %%
# Read mlb_teams.csv into a Pandas DataFrame
mlb_teams_df = pd.read_csv("mlb_teams.csv")
mlb_teams_df
# Out:
#       year league_id division_id  rank  games_played  home_games  wins  \
# 0     1876        NL         NaN     4            70         NaN    39
# 1     1876        NL         NaN     1            66         NaN    52
# 2     1876        NL         NaN     8            65         NaN     9
# 3     1876        NL         NaN     2            69         NaN    47
# 4     1876        NL         NaN     5            69         NaN    30
# ...    ...       ...         ...   ...           ...         ...   ...
# 2779  2020        NL           C     3            58        27.0    30
# 2780  2020        AL           E     1            60        29.0    40
# 2781  2020        AL           W     5            60        30.0    22
# 2782  2020        AL           E     3            60        26.0    32
# 2783  2020        NL           E     4            60        33.0    26
#
#       losses division_winner wild_card_winner  ... hits_allowed  \
# 0         31             NaN              NaN  ...          732
# 1         14             NaN              NaN  ...          608
# 2         56             NaN              NaN  ...          850
# 3         21             NaN              NaN  ...          570
# 4         36             NaN              NaN  ...          605
# ...      ...             ...              ...  ...          ...
# 2779      28               N                Y  ...          376
# 2780      20               Y                N  ...          475
# 2781      38               N                N  ...          479
# 2782      28               N                Y  ...          517
# 2783      34               N                N  ...          548
#
#      homeruns_allowed  walks_allowed  strikeouts_by_pitchers  errors  \
# 0                   7            104                      77     442
# 1                   6             29                      51     282
# 2                   9             34                      60     469
# 3                   2             27                     114     337
# 4                   3             38                     125     397
# ...               ...            ...                     ...     ...
# 2779               69            204                     464      33
# 2780               70            168                     552      33
# 2781               81            236                     489      40
# 2782               81            250                     519      38
# 2783               94            216                     508      39
#
#       double_plays  fielding_percentage                team_name  \
# 0               42                0.860          Boston Red Caps
# 1               33                0.899  Chicago White Stockings
# 2               45                0.841          Cincinnati Reds
# 3               27                0.888      Hartford Dark Blues
# 4               44                0.875         Louisville Grays
# ...            ...                  ...                      ...
# 2779            46                0.983      St. Louis Cardinals
# 2780            52                0.985           Tampa Bay Rays
# 2781            40                0.981            Texas Rangers
# 2782            47                0.982        Toronto Blue Jays
# 2783            48                0.981     Washington Nationals
#
#                        ball_park  home_attendance
# 0            South End Grounds I              NaN
# 1            23rd Street Grounds              NaN
# 2                 Avenue Grounds              NaN
# 3     Hartford Ball Club Grounds              NaN
# 4       Louisville Baseball Park              NaN
# ...                          ...              ...
# 2779           Busch Stadium III              0.0
# 2780             Tropicana Field              0.0
# 2781            Globe Life Field              0.0
# 2782                Sahlen Field              0.0
# 2783              Nationals Park              0.0
#
# [2784 rows x 41 columns]

# %%
# Use data from 1970 through 2019 because 1970
# 1970: is when batters_hit_by_pith and sacrifice_flies started being tracked
# Drop the year 2020 because it was shorted due to Covid
mlb_teams_df = mlb_teams_df.loc[(mlb_teams_df['year'] >= 1970) & (mlb_teams_df['year'] < 2020)]
mlb_teams_df
# Out:
#       year league_id division_id  rank  games_played  home_games  wins  \
# 1370  1970        NL           W     5           162        81.0    76
# 1371  1970        AL           E     1           162        81.0   108
# 1372  1970        AL           E     3           162        81.0    87
# 1373  1970        AL           W     3           162        81.0    86
# 1374  1970        AL           W     6           162        84.0    56
# ...    ...       ...         ...   ...           ...         ...   ...
# 2749  2019        NL           C     1           162        81.0    91
# 2750  2019        AL           E     2           162        81.0    96
# 2751  2019        AL           W     3           162        81.0    78
# 2752  2019        AL           E     4           162        81.0    67
# 2753  2019        NL           E     2           162        81.0    93
#
#       losses division_winner wild_card_winner  ... hits_allowed  \
# 1370      86               N              NaN  ...         1451
# 1371      54               Y              NaN  ...         1317
# 1372      75               N              NaN  ...         1391
# 1373      76               N              NaN  ...         1280
# 1374     106               N              NaN  ...         1554
# ...      ...             ...              ...  ...          ...
# 2749      71               Y                N  ...         1284
# 2750      66               N                Y  ...         1274
# 2751      84               N                N  ...         1515
# 2752      95               N                N  ...         1450
# 2753      69               N                Y  ...         1340
#
#      homeruns_allowed  walks_allowed  strikeouts_by_pitchers  errors  \
# 1370              185            478                     960     141
# 1371              139            469                     941     117
# 1372              156            594                    1003     156
# 1373              154            559                     922     127
# 1374              164            556                     762     165
# ...               ...            ...                     ...     ...
# 2749              191            545                    1399      66
# 2750              181            453                    1621      87
# 2751              241            583                    1379     105
# 2752              228            604                    1332      96
# 2753              202            517                    1511      87
#
#       double_plays  fielding_percentage             team_name  \
# 1370           118                0.977        Atlanta Braves
# 1371           148                0.981     Baltimore Orioles
# 1372           131                0.974        Boston Red Sox
# 1373           169                0.980     California Angels
# 1374           187                0.975     Chicago White Sox
# ...            ...                  ...                   ...
# 2749           168                0.989   St. Louis Cardinals
# 2750           126                0.985        Tampa Bay Rays
# 2751           143                0.982         Texas Rangers
# 2752           141                0.984     Toronto Blue Jays
# 2753           111                0.985  Washington Nationals
#
#                           ball_park  home_attendance
# 1370  Atlanta-Fulton County Stadium        1078848.0
# 1371               Memorial Stadium        1057069.0
# 1372                 Fenway Park II        1595278.0
# 1373                Anaheim Stadium        1077741.0
# 1374                  Comiskey Park         495355.0
# ...                             ...              ...
# 2749              Busch Stadium III        3480393.0
# 2750                Tropicana Field        1178735.0
# 2751   Globe Life Park in Arlington        2132994.0
# 2752                  Rogers Centre        1750114.0
# 2753                 Nationals Park        2259781.0
#
# [1384 rows x 41 columns]

# %%
# Reset the index for the DataFrame
mlb_teams_df.reset_index(drop=True, inplace=True)
mlb_teams_df
# Out:
#       year league_id division_id  rank  games_played  home_games  wins  \
# 0     1970        NL           W     5           162        81.0    76
# 1     1970        AL           E     1           162        81.0   108
# 2     1970        AL           E     3           162        81.0    87
# 3     1970        AL           W     3           162        81.0    86
# 4     1970        AL           W     6           162        84.0    56
# ...    ...       ...         ...   ...           ...         ...   ...
# 1379  2019        NL           C     1           162        81.0    91
# 1380  2019        AL           E     2           162        81.0    96
# 1381  2019        AL           W     3           162        81.0    78
# 1382  2019        AL           E     4           162        81.0    67
# 1383  2019        NL           E     2           162        81.0    93
#
#       losses division_winner wild_card_winner  ... hits_allowed  \
# 0         86               N              NaN  ...         1451
# 1         54               Y              NaN  ...         1317
# 2         75               N              NaN  ...         1391
# 3         76               N              NaN  ...         1280
# 4        106               N              NaN  ...         1554
# ...      ...             ...              ...  ...          ...
# 1379      71               Y                N  ...         1284
# 1380      66               N                Y  ...         1274
# 1381      84               N                N  ...         1515
# 1382      95               N                N  ...         1450
# 1383      69               N                Y  ...         1340
#
#      homeruns_allowed  walks_allowed  strikeouts_by_pitchers  errors  \
# 0                 185            478                     960     141
# 1                 139            469                     941     117
# 2                 156            594                    1003     156
# 3                 154            559                     922     127
# 4                 164            556                     762     165
# ...               ...            ...                     ...     ...
# 1379              191            545                    1399      66
# 1380              181            453                    1621      87
# 1381              241            583                    1379     105
# 1382              228            604                    1332      96
# 1383              202            517                    1511      87
#
#       double_plays  fielding_percentage             team_name  \
# 0              118                0.977        Atlanta Braves
# 1              148                0.981     Baltimore Orioles
# 2              131                0.974        Boston Red Sox
# 3              169                0.980     California Angels
# 4              187                0.975     Chicago White Sox
# ...            ...                  ...                   ...
# 1379           168                0.989   St. Louis Cardinals
# 1380           126                0.985        Tampa Bay Rays
# 1381           143                0.982         Texas Rangers
# 1382           141                0.984     Toronto Blue Jays
# 1383           111                0.985  Washington Nationals
#
#                           ball_park  home_attendance
# 0     Atlanta-Fulton County Stadium        1078848.0
# 1                  Memorial Stadium        1057069.0
# 2                    Fenway Park II        1595278.0
# 3                   Anaheim Stadium        1077741.0
# 4                     Comiskey Park         495355.0
# ...                             ...              ...
# 1379              Busch Stadium III        3480393.0
# 1380                Tropicana Field        1178735.0
# 1381   Globe Life Park in Arlington        2132994.0
# 1382                  Rogers Centre        1750114.0
# 1383                 Nationals Park        2259781.0
#
# [1384 rows x 41 columns]

# %%
mlb_teams_df = mlb_teams_df[['year', 'team_name', 'games_played', 'wins', 'losses', 'runs_scored', 'hits', 'doubles', 'triples', 'homeruns', 'walks',
                            'strikeouts_by_batters', 'stolen_bases', 'caught_stealing', 'batters_hit_by_pitch', 'sacrifice_flies',
                            'opponents_runs_scored', 'earned_runs_allowed', 'complete_games', 'shutouts', 'saves', 'outs_pitches',
                            'hits_allowed', 'homeruns_allowed', 'walks_allowed', 'strikeouts_by_pitchers', 'errors', 'double_plays',
                            'fielding_percentage']]
mlb_teams_df
# Out:
#       year             team_name  games_played  wins  losses  runs_scored  \
# 0     1970        Atlanta Braves           162    76      86          736
# 1     1970     Baltimore Orioles           162   108      54          792
# 2     1970        Boston Red Sox           162    87      75          786
# 3     1970     California Angels           162    86      76          631
# 4     1970     Chicago White Sox           162    56     106          633
# ...    ...                   ...           ...   ...     ...          ...
# 1379  2019   St. Louis Cardinals           162    91      71          764
# 1380  2019        Tampa Bay Rays           162    96      66          769
# 1381  2019         Texas Rangers           162    78      84          810
# 1382  2019     Toronto Blue Jays           162    67      95          726
# 1383  2019  Washington Nationals           162    93      69          873
#
#       hits  doubles  triples  homeruns  ...  shutouts  saves  outs_pitches  \
# 0     1495      215       24       160  ...         9     24          4292
# 1     1424      213       25       179  ...        12     31          4436
# 2     1450      252       28       203  ...         8     44          4339
# 3     1391      197       40       114  ...        10     49          4387
# 4     1394      192       20       123  ...         6     30          4291
# ...    ...      ...      ...       ...  ...       ...    ...           ...
# 1379  1336      246       24       210  ...        14     52          4332
# 1380  1427      291       29       217  ...        12     46          4423
# 1381  1374      296       24       223  ...         9     33          4314
# 1382  1299      270       21       247  ...         7     33          4321
# 1383  1460      298       27       231  ...        13     40          4318
#
#       hits_allowed  homeruns_allowed  walks_allowed  strikeouts_by_pitchers  \
# 0             1451               185            478                     960
# 1             1317               139            469                     941
# 2             1391               156            594                    1003
# 3             1280               154            559                     922
# 4             1554               164            556                     762
# ...            ...               ...            ...                     ...
# 1379          1284               191            545                    1399
# 1380          1274               181            453                    1621
# 1381          1515               241            583                    1379
# 1382          1450               228            604                    1332
# 1383          1340               202            517                    1511
#
#       errors  double_plays  fielding_percentage
# 0        141           118                0.977
# 1        117           148                0.981
# 2        156           131                0.974
# 3        127           169                0.980
# 4        165           187                0.975
# ...      ...           ...                  ...
# 1379      66           168                0.989
# 1380      87           126                0.985
# 1381     105           143                0.982
# 1382      96           141                0.984
# 1383      87           111                0.985
#
# [1384 rows x 29 columns]

# %%
# Create different Data Frames for different categories

# mlb_hitting_df = mlb_teams_df['hits']
# mlb_pitching_df = mlb_teams_df['shutouts']
# mlb_fielding_df = mlb_teams_df['errors']

# %%
# Convert the DataFrame into an html table
html = mlb_teams_df.to_html(index=False)

file = open("mlb_teams_data.html", "w")
file.write(html)
file.close()
