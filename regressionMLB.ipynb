# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mlb_teams_classified.csv") # change source file route if needed
df
# Out:
#       Unnamed: 0  year             team_name  games_played  wins  losses  \
# 0              0  1970        Atlanta Braves           162    76      86
# 1              1  1970     Baltimore Orioles           162   108      54
# 2              2  1970        Boston Red Sox           162    87      75
# 3              3  1970     California Angels           162    86      76
# 4              4  1970     Chicago White Sox           162    56     106
# ...          ...   ...                   ...           ...   ...     ...
# 1379        1379  2019   St. Louis Cardinals           162    91      71
# 1380        1380  2019        Tampa Bay Rays           162    96      66
# 1381        1381  2019         Texas Rangers           162    78      84
# 1382        1382  2019     Toronto Blue Jays           162    67      95
# 1383        1383  2019  Washington Nationals           162    93      69
#
#       runs_scored  hits  doubles  triples  ...  saves  outs_pitches  \
# ...

# %%
my_list = list(df)
print(*my_list,sep="\n")
# Out:
# Unnamed: 0
# year
# team_name
# games_played
# wins
# losses
# runs_scored
# hits
# doubles
# triples
# homeruns
# walks
# strikeouts_by_batters
# stolen_bases
# caught_stealing
# batters_hit_by_pitch
# sacrifice_flies
# opponents_runs_scored
# earned_runs_allowed
# complete_games
# shutouts
# saves
# outs_pitches
# hits_allowed
# homeruns_allowed
# walks_allowed
# strikeouts_by_pitchers
# errors
# double_plays
# fielding_percentage
# class

# %%
# Remove columns
df2=df.drop(["Unnamed: 0",
             "year",
             "losses",
            "team_name",
            "games_played",
            "class"],
            axis=1)
df2
# df2.dtypes
# Out:
#       wins  runs_scored  hits  doubles  triples  homeruns  walks  \
# 0       76          736  1495      215       24       160    522
# 1      108          792  1424      213       25       179    717
# 2       87          786  1450      252       28       203    594
# 3       86          631  1391      197       40       114    447
# 4       56          633  1394      192       20       123    477
# ...    ...          ...   ...      ...      ...       ...    ...
# 1379    91          764  1336      246       24       210    561
# 1380    96          769  1427      291       29       217    542
# 1381    78          810  1374      296       24       223    534
# 1382    67          726  1299      270       21       247    509
# 1383    93          873  1460      298       27       231    584
#
#       strikeouts_by_batters  stolen_bases  caught_stealing  ...  shutouts  \
# 0                       736            58               34  ...         9
# ...

# %%
my_list2 = list(df2)
print(*my_list2,sep="\n")
# Out:
# wins
# runs_scored
# hits
# doubles
# triples
# homeruns
# walks
# strikeouts_by_batters
# stolen_bases
# caught_stealing
# batters_hit_by_pitch
# sacrifice_flies
# opponents_runs_scored
# earned_runs_allowed
# complete_games
# shutouts
# saves
# outs_pitches
# hits_allowed
# homeruns_allowed
# walks_allowed
# strikeouts_by_pitchers
# errors
# double_plays
# fielding_percentage

# %%
# Assigning independent and dependent variables
X=df2.drop("wins", axis=1)
y=df2['wins'].values

# %%
# Function to get multiple regression model stats
import statsmodels.api as sm
def get_stats():
    results = sm.OLS(y, X).fit()
    print(results.summary())
    # p_values=results.pvalues #extracts p-values only
    # print(p_values)

# %%
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          3.519e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:25   Log-Likelihood:                         -3587.8
# No. Observations:                1384   AIC:                                      7224.
# Df Residuals:                    1360   BIC:                                      7349.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
# Start of stepwise regression, choosing which variables to drop based on p-value (one at a time)
X=X.drop("hits",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          3.675e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:27   Log-Likelihood:                         -3587.8
# No. Observations:                1384   AIC:                                      7222.
# Df Residuals:                    1361   BIC:                                      7342.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("double_plays",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          3.844e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:30   Log-Likelihood:                         -3587.9
# No. Observations:                1384   AIC:                                      7220.
# Df Residuals:                    1362   BIC:                                      7335.
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("fielding_percentage",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          4.030e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:32   Log-Likelihood:                         -3588.0
# No. Observations:                1384   AIC:                                      7218.
# Df Residuals:                    1363   BIC:                                      7328.
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("doubles",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          4.233e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:35   Log-Likelihood:                         -3588.3
# No. Observations:                1384   AIC:                                      7217.
# Df Residuals:                    1364   BIC:                                      7321.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("triples",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          4.456e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:38   Log-Likelihood:                         -3588.7
# No. Observations:                1384   AIC:                                      7215.
# Df Residuals:                    1365   BIC:                                      7315.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("hits_allowed",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          4.704e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:41   Log-Likelihood:                         -3589.2
# No. Observations:                1384   AIC:                                      7214.
# Df Residuals:                    1366   BIC:                                      7309.
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("caught_stealing",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          4.981e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:44   Log-Likelihood:                         -3589.6
# No. Observations:                1384   AIC:                                      7213.
# Df Residuals:                    1367   BIC:                                      7302.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("sacrifice_flies",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          5.291e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:47   Log-Likelihood:                         -3590.3
# No. Observations:                1384   AIC:                                      7213.
# Df Residuals:                    1368   BIC:                                      7296.
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("strikeouts_by_batters",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          5.640e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:50   Log-Likelihood:                         -3591.3
# No. Observations:                1384   AIC:                                      7213.
# Df Residuals:                    1369   BIC:                                      7291.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("batters_hit_by_pitch",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          6.039e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:52   Log-Likelihood:                         -3592.1
# No. Observations:                1384   AIC:                                      7212.
# Df Residuals:                    1370   BIC:                                      7286.
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("stolen_bases",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          6.494e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:55   Log-Likelihood:                         -3593.7
# No. Observations:                1384   AIC:                                      7213.
# Df Residuals:                    1371   BIC:                                      7281.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("homeruns_allowed",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          7.026e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:45:58   Log-Likelihood:                         -3595.1
# No. Observations:                1384   AIC:                                      7214.
# Df Residuals:                    1372   BIC:                                      7277.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
X=X.drop("homeruns",axis=1)
get_stats()
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.998
# Model:                            OLS   Adj. R-squared (uncentered):              0.998
# Method:                 Least Squares   F-statistic:                          7.661e+04
# Date:                Tue, 21 Mar 2023   Prob (F-statistic):                        0.00
# Time:                        05:46:01   Log-Likelihood:                         -3595.9
# No. Observations:                1384   AIC:                                      7214.
# Df Residuals:                    1373   BIC:                                      7271.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %%
# Independent variables after stepwise regression
print(X.columns)
print(len(X.columns)," variables")
# Out:
# Index(['runs_scored', 'walks', 'opponents_runs_scored', 'earned_runs_allowed',
#        'complete_games', 'shutouts', 'saves', 'outs_pitches', 'walks_allowed',
#        'strikeouts_by_pitchers', 'errors'],
#       dtype='object')
# 11  variables

# %%
# Testing for collinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
print(vif_data)
# Out:
#                    feature          VIF
# 0              runs_scored   144.002115
# 1                    walks    90.634032
# 2    opponents_runs_scored  5963.889461
# 3      earned_runs_allowed  5304.605335
# 4           complete_games     8.004783
# 5                 shutouts    13.217682
# 6                    saves    43.663092
# 7             outs_pitches   557.973876
# 8            walks_allowed   102.095837
# 9   strikeouts_by_pitchers    64.552274
# 10                  errors   101.180088

# %%
# From theresults above, we can see that "opponents_runs_scored" and "earned_runs_allowed" are highly correlated. Thus we will drop "earned_runs_allowed" from the dataset
X=X.drop("earned_runs_allowed",axis=1)

# %%
# Independent variables after collinearity test
print(X.columns)
print(len(X.columns)," variables")
# Out:
# Index(['runs_scored', 'walks', 'opponents_runs_scored', 'complete_games',
#        'shutouts', 'saves', 'outs_pitches', 'walks_allowed',
#        'strikeouts_by_pitchers', 'errors'],
#       dtype='object')
# 10  variables

# %%
# Create CSV file with final dataset
final_df=df.drop(["Unnamed: 0",
             "hits",
             "double_plays",
            "fielding_percentage",
            "doubles",
            "triples",
            "hits_allowed",
            "caught_stealing",
            "sacrifice_flies",
            "strikeouts_by_batters",
            "batters_hit_by_pitch",
            "stolen_bases",
            "homeruns_allowed",
            "homeruns",
            "earned_runs_allowed"
            ],
            axis=1)
final_df.to_csv("mlb_teams_final.csv")
final_df
# Out:
#       year             team_name  games_played  wins  losses  runs_scored  \
# 0     1970        Atlanta Braves           162    76      86          736
# 1     1970     Baltimore Orioles           162   108      54          792
# 2     1970        Boston Red Sox           162    87      75          786
# 3     1970     California Angels           162    86      76          631
# 4     1970     Chicago White Sox           162    56     106          633
# ...    ...                   ...           ...   ...     ...          ...
# 1379  2019   St. Louis Cardinals           162    91      71          764
# 1380  2019        Tampa Bay Rays           162    96      66          769
# 1381  2019         Texas Rangers           162    78      84          810
# 1382  2019     Toronto Blue Jays           162    67      95          726
# 1383  2019  Washington Nationals           162    93      69          873
#
#       walks  opponents_runs_scored  complete_games  shutouts  saves  \
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
score = model.score(X, y)
print(f"R2 Score: {score}")
print('y-axis intercept: ', model.intercept_) 
list(zip(X, model.coef_))
coeff_table=pd.DataFrame(list(zip(X, model.coef_)))
coeff_table = coeff_table.rename(columns={0: 'X', 1: 'Coefficient'})
coeff_table.to_csv("coefficient_table.csv")
coeff_table
# Out:
# R2 Score: 0.9304714673783749
# y-axis intercept:  -0.7321127684871129
#                         X  Coefficient
# 0             runs_scored     0.085938
# 1                   walks     0.003817
# 2   opponents_runs_scored    -0.069766
# 3          complete_games     0.158750
# 4                shutouts     0.195620
# 5                   saves     0.363825
# 6            outs_pitches     0.011554
# 7           walks_allowed    -0.004081
# 8  strikeouts_by_pitchers     0.003135
# 9                  errors    -0.015329

# %%
import seaborn as sns
sns.set()
cols = ['wins',
        'runs_scored',
        'walks',
        'opponents_runs_scored',
        'complete_games',
        'shutouts',
        'saves',
        'outs_pitches',
        'walks_allowed',
        'strikeouts_by_pitchers',
        'errors']
sns.pairplot(df2[cols], kind='reg', plot_kws={'line_kws':{'color':'red'}}, height = 2.5) 
plt.savefig('pairplots.png')
plt.show()

# %%
predictions = model.predict(X)
predictions_table=pd.DataFrame({"Predicted": predictions, "Actual": y, "Error": predictions - y})[["Predicted", "Actual", "Error"]]
predictions_table.to_csv("predictions_table.csv")
predictions_table
# Out:
#        Predicted  Actual     Error
# 0      76.777022      76  0.777022
# 1     103.671238     108 -4.328762
# 2      90.781272      87  3.781272
# 3      83.717870      86 -2.282130
# 4      60.574146      56  4.574146
# ...          ...     ...       ...
# 1379   93.901532      91  2.901532
# 1380   93.745369      96 -2.254631
# 1381   74.244092      78 -3.755908
# 1382   69.536459      67  2.536459
# 1383   94.451316      93  1.451316
#
# [1384 rows x 3 columns]

# %%
predictions = model.predict(X)
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()

# %%
# Fit the model to the training data, and calculate the scores for the training and testing data.

model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.9303466731994289
# Testing Score: 0.9297116942632093
